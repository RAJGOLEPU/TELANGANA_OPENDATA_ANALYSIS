# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('just testing that git from google colab working properly')
# Out:
# just testing that git from google colab working properly
